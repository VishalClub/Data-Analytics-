# %%
import pandas as pd

# add data set
df = pd.read_csv('cleaned_dataset.csv')

df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  \
# 0             0           0
# 1             1           1
# 2             2           2
# 3             3           3
# 4             4           4
#
#                                                 Text    Sentiment  \
# 0   Enjoying a beautiful day at the park!        ...   Positive
# 1   Traffic was terrible this morning.           ...   Negative
# 2   Just finished an amazing workout! 💪          ...   Positive
# 3   Excited about the upcoming weekend getaway!  ...   Positive
# 4   Trying out a new recipe for dinner tonight.  ...   Neutral
#
#           Timestamp            User     Platform  \
# 0  15-01-2023 12:30   User123          Twitter
# 1  15-01-2023 08:45   CommuterX        Twitter
# 2  15-01-2023 15:45   FitnessFan      Instagram
# 3  15-01-2023 18:20   AdventureX       Facebook
# 4  15-01-2023 19:55   ChefCook        Instagram
#
#                                      Hashtags  Retweets  Likes       Country  \
# ...

# %%
#Dataset shap and info
print(df.shape)
df.info

#statistics
df.describe()

# check mising value
df.isnull().sum()
# Out:
# (732, 15)
# Unnamed: 0.1    0
# Unnamed: 0      0
# Text            0
# Sentiment       0
# Timestamp       0
# User            0
# Platform        0
# Hashtags        0
# Retweets        0
# Likes           0
# Country         0
# Year            0
# Month           0
# Day             0
# Hour            0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set (style="whitegrid")

# %%
#Distribution of Likes
plt.figure(figsize=(8,5))
sns.histplot(df['Likes'], bins=15, kde=True, color='skyblue')
plt.title("Distribution of Likes")
plt.xlabel("Likes")
plt.ylabel("Frequency")
plt.tight_layout()
plt.show()

# %%
#Likes by Country
plt.figure(figsize=(10, 10))
#sns.boxplot(x='Country', y='Likes', data=df, palette='Set2')
sns.boxplot(data=df, x='Platform', y='Likes')
plt.title("Likes Distribution Country wise")
plt.show()

# %%
#Likes vs Hour colored by Platform
plt.figure(figsize=(8, 5))
sns.scatterplot(x='Hour', y='Likes', hue='Platform', data=df, palette='Set1', s=100)
plt.title("Scatter Plot of Likes by Hour across Platforms")
plt.xlabel("Hour of Day")
plt.ylabel("Likes")
plt.tight_layout()
plt.show()

# %%
#descriptive statistics
print("Statistics for Numerical Features:\n")
print(df.describe())

#Extract only numerical features
numerical_features = df.select_dtypes(include=['int64', 'float64'])

#Compute the correlation matrix
correlation_matrix = numerical_features.corr()

print("\nCorrelation Matrix:\n")
print(correlation_matrix)

# Visualize correlation matrix with heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm', linewidths=0.5, linecolor='white')
plt.title("Correlation Matrix Heatmap of Numerical Features")
plt.xticks(rotation=45)
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()
# Out:
# Statistics for Numerical Features:
#
#        Unnamed: 0.1  Unnamed: 0    Retweets       Likes         Year  \
# count    732.000000  732.000000  732.000000  732.000000   732.000000
# mean     366.464481  369.740437   21.508197   42.901639  2020.471311
# std      211.513936  212.428936    7.061286   14.089848     2.802285
# min        0.000000    0.000000    5.000000   10.000000  2010.000000
# 25%      183.750000  185.750000   17.750000   34.750000  2019.000000
# 50%      366.500000  370.500000   22.000000   43.000000  2021.000000
# 75%      549.250000  553.250000   25.000000   50.000000  2023.000000
# max      732.000000  736.000000   40.000000   80.000000  2023.000000
#
#             Month         Day        Hour
# count  732.000000  732.000000  732.000000
# mean     6.122951   15.497268   15.521858
# std      3.411763    8.474553    4.113414
# min      1.000000    1.000000    0.000000
# 25%      3.000000    9.000000   13.000000
# 50%      6.000000   15.000000   16.000000
# ...
